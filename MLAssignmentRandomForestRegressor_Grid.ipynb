# %% [markdown]
# <a href="https://colab.research.google.com/github/MangalaPriyadharshini/MangalaPriyadharshini/blob/main/MLAssignmentRandomForestRegressor_Grid.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing the Libraies
import numpy as np
import pandas as pd

# %%
# Reading the Dataset
dataset = pd.read_csv('insurance_pre.csv')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
indep=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dep=dataset[['charges']]

# %%
#split into training set and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(indep, dep, test_size = 0.20, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
param_grid = {
    'n_estimators': [1, 5, 10],
    'criterion': ['squared_error', 'absolute_error', 'poisson'],
    # 'max_depth': [None, 10, 20],
    # 'min_samples_split': [2, 5],
    # 'min_samples_leaf': [1, 2],
    # 'min_weight_fraction_leaf': [0.0, 0.1],
    # 'max_features': ['sqrt', 'log2', None],
    # 'max_leaf_nodes': [None, 50],
    # 'min_impurity_decrease': [0.0, 0.01],
    # 'bootstrap': [True, False],
    # 'oob_score': [True, False],
    # 'warm_start': [True, False],
    # 'ccp_alpha': [0.0, 0.01],
    # 'max_samples': [None, 0.5]
}
grid = GridSearchCV(RandomForestRegressor(), param_grid, refit = True, verbose = 3 ,n_jobs=-1)
# fitting the model for grid search
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'poisson'],
#                          'n_estimators': [1, 5, 10]},
#              verbose=3)

# %%
# Assuming 'grid' is your GridSearchCV object and has been fitted to the data
print("Best parameters:", grid.best_params_)
# Access the mean test score for the best parameters
best_index = grid.best_index_
best_r2_score = grid.cv_results_['mean_test_score'][best_index]
# Printing the best R² score
print("r2:",best_r2_score)
# Out:
# Best parameters: {'criterion': 'poisson', 'n_estimators': 10}
# r2: 0.798083189443981

# %%
table=pd.DataFrame.from_dict(grid.cv_results_)

# %%
table.sort_values('rank_test_score')
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 8       0.062672      0.012868         0.004674        0.000781
# 5       0.192887      0.001500         0.004689        0.000119
# 2       0.065629      0.011354         0.004815        0.000042
# 1       0.030187      0.001163         0.004019        0.000425
# 7       0.033904      0.003201         0.003759        0.000107
# 4       0.098605      0.002460         0.004144        0.000602
# 3       0.024115      0.002907         0.003255        0.000134
# 0       0.010093      0.000969         0.003338        0.000401
# 6       0.011609      0.002471         0.002758        0.000121
#
#   param_criterion  param_n_estimators  \
# 8         poisson                  10
# 5  absolute_error                  10
# 2   squared_error                  10
# 1   squared_error                   5
# 7         poisson                   5
# 4  absolute_error                   5
# 3  absolute_error                   1
# 0   squared_error                   1
# 6         poisson                   1
#
#                                               params  split0_test_score  \
# 8       {'criterion': 'poisson', 'n_estimators': 10}           0.838180
# 5  {'criterion': 'absolute_error', 'n_estimators'...           0.839753
# 2  {'criterion': 'squared_error', 'n_estimators':...           0.828163
# 1  {'criterion': 'squared_error', 'n_estimators': 5}           0.839135
# 7        {'criterion': 'poisson', 'n_estimators': 5}           0.836104
# 4  {'criterion': 'absolute_error', 'n_estimators'...           0.828918
# 3  {'criterion': 'absolute_error', 'n_estimators'...           0.749822
# 0  {'criterion': 'squared_error', 'n_estimators': 1}           0.665993
# 6        {'criterion': 'poisson', 'n_estimators': 1}           0.649330
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 8           0.819002           0.784178           0.797463           0.751593
# 5           0.799445           0.781703           0.816546           0.752737
# 2           0.800723           0.779754           0.804692           0.765836
# 1           0.776539           0.768254           0.789816           0.740367
# 7           0.799747           0.748065           0.773155           0.755137
# 4           0.797708           0.733747           0.745751           0.730104
# 3           0.688787           0.542766           0.653579           0.620125
# 0           0.555576           0.662708           0.656193           0.692771
# 6           0.663369           0.569022           0.636547           0.624919
#
#    mean_test_score  std_test_score  rank_test_score
# 8         0.798083        0.029666                1
# 5         0.798037        0.029677                2
# 2         0.795834        0.021476                3
# 1         0.782822        0.032478                4
# 7         0.782442        0.032226                5
# 4         0.767246        0.039230                6
# 3         0.651016        0.069092                7
# 0         0.646648        0.047212                8
# 6         0.628637        0.032449                9

# %%
# Assuming 'grid' is your GridSearchCV object that has been fitted to the data
best_model = grid.best_estimator_

# %%
import pickle
filename="RF_G.sav"
pickle.dump(best_model,open(filename,'wb'))

# %%
loaded_model = pickle.load(open(filename, 'rb'))

# %%
result=loaded_model.predict([[30,30,2,1,0]])

# %%
result
# Out:
# array([15796.12805])
